# %% [markdown]
# <a href="https://colab.research.google.com/github/ChangHuaHua/QM2-Group-12/blob/main/Summary_Statistics_Female_Education.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Commands and Data Uploading

# %%
import pandas as pd 
import pylab
import matplotlib.pyplot as plt

# %%
#Uploading the Cleaned Female Education Dataset 

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdad5d62-4ea5-4083-a454-6963cdaf9982" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdad5d62-4ea5-4083-a454-6963cdaf9982">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2. Female Education - Cleaned + Country.csv.zip to 2. Female Education - Cleaned + Country.csv.zip

# %%
data_path = "/content/2. Female:Education:Cleaned:Country.csv"
female_edu= pd.read_csv(data_path, index_col=0)
female_edu
# Out:
#      Reference Area  Time Period  Observation Value
# 0       Afghanistan       2014.0           34.62152
# 1       Afghanistan       2013.0           34.43871
# 2       Afghanistan       2012.0           34.63026
# 3       Afghanistan       2011.0           34.45594
# 4       Afghanistan       2010.0           32.00865
# ...             ...          ...                ...
# 4972       Zimbabwe       1979.0           45.30896
# 4973       Zimbabwe       1978.0           43.32329
# 4974       Zimbabwe       1977.0           42.61502
# 4975       Zimbabwe       1976.0           41.88793
# 4976       Zimbabwe       1975.0           41.49989
#
# [4977 rows x 3 columns]

# %% [markdown]
# # Cleaning the dataframe

# %%
#cleaning Time period by converting the string to integer 
female_edu['Time Period'] = female_edu['Time Period'].fillna(0).astype(int)
female_edu
# Out:
#      Reference Area  Time Period  Observation Value
# 0       Afghanistan         2014           34.62152
# 1       Afghanistan         2013           34.43871
# 2       Afghanistan         2012           34.63026
# 3       Afghanistan         2011           34.45594
# 4       Afghanistan         2010           32.00865
# ...             ...          ...                ...
# 4972       Zimbabwe         1979           45.30896
# 4973       Zimbabwe         1978           43.32329
# 4974       Zimbabwe         1977           42.61502
# 4975       Zimbabwe         1976           41.88793
# 4976       Zimbabwe         1975           41.49989
#
# [4977 rows x 3 columns]

# %%
#narrowing the timeframe down as most values lie between 1975-2014

female_edu= female_edu[female_edu['Time Period'] <= 2014]
female_edu= female_edu[female_edu['Time Period'] >= 1975]
female_edu.reset_index(drop=True)
female_edu
# Out:
#      Reference Area  Time Period  Observation Value
# 0       Afghanistan         2014           34.62152
# 1       Afghanistan         2013           34.43871
# 2       Afghanistan         2012           34.63026
# 3       Afghanistan         2011           34.45594
# 4       Afghanistan         2010           32.00865
# ...             ...          ...                ...
# 4972       Zimbabwe         1979           45.30896
# 4973       Zimbabwe         1978           43.32329
# 4974       Zimbabwe         1977           42.61502
# 4975       Zimbabwe         1976           41.88793
# 4976       Zimbabwe         1975           41.49989
#
# [4937 rows x 3 columns]

# %% [markdown]
# # Reshaping the data

# %%
#reshaping the dataframe 

female_edu_reshaped = female_edu.pivot_table(index='Reference Area', columns='Time Period', values='Observation Value')
female_edu_reshaped.head()
# Out:
# Time Period         1975      1976      1977  ...      2012      2013      2014
# Reference Area                                ...
# Afghanistan     11.99690  12.77423  14.24530  ...  34.63026  34.43871  34.62152
# Albania              NaN  46.62673       NaN  ...  47.16365  46.91698  46.59472
# Algeria         33.02334  33.62559  34.29436  ...       NaN       NaN       NaN
# Andorra         47.57282  62.29321       NaN  ...  48.00380  48.00661  47.99722
# Angola               NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# [5 rows x 40 columns]

# %%
#saving new file 

female_edu_reshaped.to_csv('Female Education Reshaped.csv')

# %% [markdown]
# # Summary Statistics: Female Education

# %% [markdown]
# Summary Statistics at global scale for each year

# %%
female_edu_reshaped.describe()
# Out:
# Time Period        1975        1976  ...        2013        2014
# count        106.000000  112.000000  ...  139.000000  118.000000
# mean          42.366779   41.886035  ...   48.310549   48.049255
# std           11.472943   12.061368  ...    5.101735    5.426691
# min            0.000000    0.000000  ...    0.000000    0.000000
# 25%           32.786865   33.294997  ...   47.787270   47.791438
# 50%           46.607010   46.424450  ...   48.845650   48.884590
# 75%           49.822288   50.103797  ...   50.249490   50.013733
# max           70.449510   75.063310  ...   57.650110   57.323670
#
# [8 rows x 40 columns]

# %% [markdown]
# # Creating Dataframe with only African countries

# %%
#creating a new dataframe with only African countries
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e081966f-115c-4ee2-8f58-1eef91f4dc15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e081966f-115c-4ee2-8f58-1eef91f4dc15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Africa_FULL_MERGE.csv.zip to Africa_FULL_MERGE.csv.zip

# %%
africa = "/content/Africa_FULL_MERGE.csv"
female_edu_africa = pd.read_csv(africa, index_col=0, encoding='latin1')

#narrowing table down to Female education

female_edu_africa = female_edu_africa[['Country', 'Region', 'Year','Females in secondary education (%)']]
female_edu_africa.head()
# Out:
#   Country                      Region  Year  Females in secondary education (%)
# 0   Libya  Middle East & North Africa  1960                                 NaN
# 1   Libya  Middle East & North Africa  1961                                 NaN
# 2   Libya  Middle East & North Africa  1962                                 NaN
# 3   Libya  Middle East & North Africa  1963                                 NaN
# 4   Libya  Middle East & North Africa  1964                                 NaN

# %%
#narrowing down timeframe as Female Education data recorded mainly between 1975-2014
female_edu_africa= female_edu_africa[female_edu_africa['Year'] <= 2014]
female_edu_africa = female_edu_africa[female_edu_africa['Year'] >= 1975]
female_edu_africa.reset_index(drop=True)
female_edu_africa
# Out:
#        Country  ... Females in secondary education (%)
# 15       Libya  ...                                NaN
# 16       Libya  ...                                NaN
# 17       Libya  ...                                NaN
# 18       Libya  ...                                NaN
# 19       Libya  ...                                NaN
# ...        ...  ...                                ...
# 3118  Zimbabwe  ...                                NaN
# 3119  Zimbabwe  ...                                NaN
# 3120  Zimbabwe  ...                           49.31144
# 3121  Zimbabwe  ...                           49.57466
# 3122  Zimbabwe  ...                                NaN
#
# [2120 rows x 4 columns]

# %%
#Reshaping the Data 

female_edu_africa_new = female_edu_africa.pivot_table(index=['Country', 'Region'], columns='Year', values='Females in secondary education (%)')
female_edu_africa_new.head()
# Out:
# Year                                         1975      1976  ...      2013      2014
# Country      Region                                          ...
# Algeria      Middle East & North Africa  33.02334  33.62559  ...       NaN       NaN
# Angola       Sub-Saharan Africa               NaN       NaN  ...       NaN       NaN
# Benin        Sub-Saharan Africa          32.70804       NaN  ...  39.55673  40.22902
# Botswana     Sub-Saharan Africa          51.92496  53.30876  ...  51.00716       NaN
# Burkina Faso Sub-Saharan Africa          30.73691  31.57084  ...  44.98252  45.73683
#
# [5 rows x 40 columns]

# %%
#saving new file

female_edu_africa_new.to_csv('Female Education Africa.csv')

# %% [markdown]
# # Summary Statistics for Female Education at African scale

# %% [markdown]
# Summary statistics for each year at african scale

# %%
female_edu_africa_new.describe()
# Out:
# Year        1975       1976       1977  ...       2012       2013       2014
# count  25.000000  30.000000  29.000000  ...  29.000000  26.000000  20.000000
# mean   34.219934  33.423239  34.367138  ...  46.049184  47.134077  46.260311
# std     9.209528  10.404171   9.683983  ...   5.438783   4.308571   4.768427
# min    23.220080  16.604020  17.943970  ...  31.128690  38.101670  38.151090
# 25%    27.571830  26.715390  28.284890  ...  43.949840  44.924867  42.749538
# 50%    31.456830  31.624995  33.051830  ...  46.482810  47.438555  46.901170
# 75%    37.195560  35.744608  37.126040  ...  48.872680  50.066585  49.312197
# max    56.246690  56.802470  57.821160  ...  57.791190  57.650110  57.323670
#
# [8 rows x 40 columns]

# %%
#we see that 48% of female were enrolled in Secondary Education in 2014 at global scale versus 46% at African scale.

# %% [markdown]
# # Summary statistics : Niger and Tunisia

# %% [markdown]
# **Niger**

# %%
#narrowing down to Niger
female_edu_niger = female_edu_africa[female_edu_africa['Country'] == 'Niger']
female_edu_niger_2 = female_edu_niger.reset_index(drop=True)
female_edu_niger_2 = female_edu_niger[['Country', 'Region', 'Year', 'Females in secondary education (%)']]
female_edu_niger_2
# Out:
#      Country              Region  Year  Females in secondary education (%)
# 2198   Niger  Sub-Saharan Africa  1975                            26.77370
# 2199   Niger  Sub-Saharan Africa  1976                            27.54114
# 2200   Niger  Sub-Saharan Africa  1977                            28.28489
# 2201   Niger  Sub-Saharan Africa  1978                            28.47914
# 2202   Niger  Sub-Saharan Africa  1979                            27.32387
# 2203   Niger  Sub-Saharan Africa  1980                            28.10292
# 2204   Niger  Sub-Saharan Africa  1981                            29.16549
# 2205   Niger  Sub-Saharan Africa  1982                                 NaN
# 2206   Niger  Sub-Saharan Africa  1983                                 NaN
# 2207   Niger  Sub-Saharan Africa  1984                                 NaN
# 2208   Niger  Sub-Saharan Africa  1985                                 NaN
# ...

# %%
#pivoting the dataframe 

female_edu_niger_new = female_edu_niger_2.pivot_table(index=['Country', 'Region'], columns='Year', values='Females in secondary education (%)')
female_edu_niger_new.head()
# Out:
# Year                           1975      1976  ...      2013      2014
# Country Region                                 ...
# Niger   Sub-Saharan Africa  26.7737  27.54114  ...  40.44244  41.32214
#
# [1 rows x 32 columns]

# %%
#summary statistics 

female_edu_niger_new.describe()
# Out:
# Year      1975      1976      1977  ...      2012      2013      2014
# count   1.0000   1.00000   1.00000  ...   1.00000   1.00000   1.00000
# mean   26.7737  27.54114  28.28489  ...  40.05162  40.44244  41.32214
# std        NaN       NaN       NaN  ...       NaN       NaN       NaN
# min    26.7737  27.54114  28.28489  ...  40.05162  40.44244  41.32214
# 25%    26.7737  27.54114  28.28489  ...  40.05162  40.44244  41.32214
# 50%    26.7737  27.54114  28.28489  ...  40.05162  40.44244  41.32214
# 75%    26.7737  27.54114  28.28489  ...  40.05162  40.44244  41.32214
# max    26.7737  27.54114  28.28489  ...  40.05162  40.44244  41.32214
#
# [8 rows x 32 columns]

# %% [markdown]
# **Tunisia**

# %%
#narrowing down to Tunisia

female_edu_tunisia= female_edu_africa[small_female_edu_africa['Country'] == 'Tunisia']
female_edu_tunisia_2 = female_edu_tunisia.reset_index(drop=True)
female_edu_tunisia_2 = female_edu_tunisia[['Country', 'Region', 'Year', 'Females in secondary education (%)']]
female_edu_tunisia_2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#      Country  ... Females in secondary education (%)
# 74   Tunisia  ...                           31.45683
# 75   Tunisia  ...                           33.67485
# 76   Tunisia  ...                           35.18020
# 77   Tunisia  ...                           35.57649
# 78   Tunisia  ...                           36.09676
# 79   Tunisia  ...                           36.45194
# 80   Tunisia  ...                           36.64253
# 81   Tunisia  ...                           37.26337
# 82   Tunisia  ...                           37.62435
# 83   Tunisia  ...                           38.38816
# 84   Tunisia  ...                           39.65617
# 85   Tunisia  ...                           40.11538
# 86   Tunisia  ...                           41.08388
# ...

# %%
#pivoting the dataframe 

female_edu_tunisia_new = female_edu_tunisia_2.pivot_table(index=['Country', 'Region'], columns='Year', values='Females in secondary education (%)')
female_edu_tunisia_new.head()
# Out:
# Year                                    1975      1976  ...      2010      2011
# Country Region                                          ...
# Tunisia Middle East & North Africa  31.45683  33.67485  ...  50.38128  49.83583
#
# [1 rows x 34 columns]

# %%
#summary statistics

female_edu_tunisia_new.describe()
# Out:
# Year       1975      1976     1977  ...      2009      2010      2011
# count   1.00000   1.00000   1.0000  ...   1.00000   1.00000   1.00000
# mean   31.45683  33.67485  35.1802  ...  50.48842  50.38128  49.83583
# std         NaN       NaN      NaN  ...       NaN       NaN       NaN
# min    31.45683  33.67485  35.1802  ...  50.48842  50.38128  49.83583
# 25%    31.45683  33.67485  35.1802  ...  50.48842  50.38128  49.83583
# 50%    31.45683  33.67485  35.1802  ...  50.48842  50.38128  49.83583
# 75%    31.45683  33.67485  35.1802  ...  50.48842  50.38128  49.83583
# max    31.45683  33.67485  35.1802  ...  50.48842  50.38128  49.83583
#
# [8 rows x 34 columns]
