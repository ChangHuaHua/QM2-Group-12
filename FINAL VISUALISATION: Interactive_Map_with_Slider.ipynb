# %% [markdown]
# <a href="https://colab.research.google.com/github/ChangHuaHua/QM2-Group-12/blob/main/Interactive_Map_with_Slider.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Code is based on:
#https://community.plotly.com/t/using-a-slider-with-a-choropleth-map-and-the-data-is-not-appearing-sequentially/21510/2

# %%
import pandas as pd
! pip install plotly==4.5
# Out:
# ...
#      |████████████████████████████████| 7.1MB 6.2MB/s
# ...
#   Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# ...

# %%
import plotly
import plotly.express as px

# %%
#upload 1b. TFR_Africa_Cleaned.csv and Africa geoJSON file
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b53d5129-06bc-4f4b-bb95-15f350aec916" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b53d5129-06bc-4f4b-bb95-15f350aec916">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1b. TFR_Africa_Cleaned.csv to 1b. TFR_Africa_Cleaned.csv

# %%
tfr = pd.read_csv('/content/1b. TFR_Africa_Cleaned.csv', encoding='latin1')
tfr.head()
# Out:
#    Unnamed: 0  Country Name  ...              Region          IncomeGroup
# 0           0        Angola  ...  Sub-Saharan Africa  Lower middle income
# 1           1       Burundi  ...  Sub-Saharan Africa           Low income
# 2           2         Benin  ...  Sub-Saharan Africa  Lower middle income
# 3           3  Burkina Faso  ...  Sub-Saharan Africa           Low income
# 4           4      Botswana  ...  Sub-Saharan Africa  Upper middle income
#
# [5 rows x 65 columns]

# %%
tfr_melt = pd.melt(tfr, id_vars=['Country Name', 'Country Code'], value_vars=['1960', '1961',	'1962',	'1963',	'1964',	'1965',	'1966',	'1967', '1968',	'1969',	'1970',	'1971',	'1972',	'1973',	'1974',	'1975',	'1976',	'1977',	'1978',	'1979',	'1980',	'1981',	'1982',	'1983',	'1984',	'1985',	'1986',	'1987',	'1988',	'1989',	'1990',	'1991',	'1992',	'1993',	'1994',	'1995',	'1996', '1997',	'1998',	'1999',	'2000',	'2001',	'2002',	'2003',	'2004',	'2005',	'2006',	'2007', '2008',	'2009',	'2010',	'2011',	'2012',	'2013',	'2014',	'2015',	'2016',	'2017',	'2018'],var_name='year', value_name='TFR').sort_values('Country Name')

# %%
tfr_melt.head()
# Out:
#      Country Name Country Code  year    TFR
# 967       Algeria          DZA  1977  7.234
# 913       Algeria          DZA  1976  7.344
# 2803      Algeria          DZA  2011  2.909
# 1507      Algeria          DZA  1987  5.412
# 2209      Algeria          DZA  2000  2.514

# %%
tfr_sorted = tfr_melt.sort_values(['Country Name', 'year'])
tfr_sorted.head()
# Out:
#     Country Name Country Code  year    TFR
# 49       Algeria          DZA  1960  7.524
# 103      Algeria          DZA  1961  7.573
# 157      Algeria          DZA  1962  7.614
# 211      Algeria          DZA  1963  7.646
# 265      Algeria          DZA  1964  7.665

# %%
tfr_slider = tfr_sorted.reset_index(drop=True)
tfr_slider.head()
# Out:
#   Country Name Country Code  year    TFR
# 0      Algeria          DZA  1960  7.524
# 1      Algeria          DZA  1961  7.573
# 2      Algeria          DZA  1962  7.614
# 3      Algeria          DZA  1963  7.646
# 4      Algeria          DZA  1964  7.665

# %%
px.choropleth(tfr_slider, scope ="africa", locations="Country Code", color="TFR", hover_name="Country Name", animation_frame="year",
             color_continuous_scale=px.colors.sequential.YlOrBr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="73cd3846-9188-4f58-9c3e-dfe6cc1c3d49" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("73cd3846-9188-4f58-9c3e-dfe6cc1c3d49")) {
#                     Plotly.newPlot(
#                         '73cd3846-9188-4f58-9c3e-dfe6cc1c3d49',
# ...
