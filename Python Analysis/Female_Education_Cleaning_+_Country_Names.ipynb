# %% [markdown]
# <a href="https://colab.research.google.com/github/ChangHuaHua/QM2-Group-12/blob/main/Female_Education_Cleaning_%2B_Country_Names.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-be5a70b7-3f2d-422e-b1fe-0ec073748ff6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be5a70b7-3f2d-422e-b1fe-0ec073748ff6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2. Female Education.csv to 2. Female Education.csv

# %%
# !mkdir data
# !mkdir 2.\ Female\ Education.csv

import pandas
# Out:
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘2. Female Education.csv’: File exists

# %%
dataset_FemaleEducation = "2. Female Education.csv"
#file "2. Female Education.csv" contains 4978 samples

FemaleEducation = pandas.read_csv(dataset_FemaleEducation)
FemaleEducation.head()
# Out:
#   Reference Area  Time Period  ... Units of measurement Observation Value
# 0    Afghanistan         2014  ...              Percent          34.62152
# 1    Afghanistan         2013  ...              Percent          34.43871
# 2    Afghanistan         2012  ...              Percent          34.63026
# 3    Afghanistan         2011  ...              Percent          34.45594
# 4    Afghanistan         2010  ...              Percent          32.00865
#
# [5 rows x 6 columns]

# %%
FemaleEducation.tail()
# Out:
#      Reference Area  Time Period  ... Units of measurement Observation Value
# 4972       Zimbabwe         1979  ...              Percent          45.30896
# 4973       Zimbabwe         1978  ...              Percent          43.32329
# 4974       Zimbabwe         1977  ...              Percent          42.61502
# 4975       Zimbabwe         1976  ...              Percent          41.88793
# 4976       Zimbabwe         1975  ...              Percent          41.49989
#
# [5 rows x 6 columns]

# %%
clean = FemaleEducation[['Reference Area', 'Time Period', 'Observation Value']]
clean.head()
# Out:
#   Reference Area  Time Period  Observation Value
# 0    Afghanistan         2014           34.62152
# 1    Afghanistan         2013           34.43871
# 2    Afghanistan         2012           34.63026
# 3    Afghanistan         2011           34.45594
# 4    Afghanistan         2010           32.00865

# %%
clean.to_csv('2. Female Education - Cleaning.csv')

# %%
clean = clean.replace('United Republic of Tanzania', 'Tanzania', regex=True)
clean.loc[4800:4835]
# Out:
#                                          Reference Area  ...  Observation Value
# 4800  United Kingdom of Great Britain and Northern I...  ...           49.50804
# 4801  United Kingdom of Great Britain and Northern I...  ...           49.38907
# 4802  United Kingdom of Great Britain and Northern I...  ...           49.29419
# 4803  United Kingdom of Great Britain and Northern I...  ...           49.16104
# 4804  United Kingdom of Great Britain and Northern I...  ...           49.09871
# 4805  United Kingdom of Great Britain and Northern I...  ...           49.00588
# 4806  United Kingdom of Great Britain and Northern I...  ...           48.91905
# 4807                                           Tanzania  ...           47.72696
# 4808                                           Tanzania  ...           46.48281
# 4809                                           Tanzania  ...           44.76647
# 4810                                           Tanzania  ...           44.35805
# ...

# %%
clean = clean.replace('Democratic Republic of the Congo', 'Democratic Republic of Congo', regex=True)
clean.loc[1210:1245]
# Out:
#                              Reference Area  Time Period  Observation Value
# 1210                         Czech Republic         1979           50.00705
# 1211                         Czech Republic         1978           49.96792
# 1212                         Czech Republic         1977           49.95652
# 1213                         Czech Republic         1976           49.96231
# 1214                         Czech Republic         1975           49.98776
# 1215  Democratic People's Republic of Korea         2009           48.91810
# 1216           Democratic Republic of Congo         2014           38.15109
# 1217           Democratic Republic of Congo         2013           38.10167
# 1218           Democratic Republic of Congo         2012           37.00663
# 1219           Democratic Republic of Congo         2011           36.82266
# 1220           Democratic Republic of Congo         2010           36.40054
# ...

# %%
clean.to_csv('2. Female Education - Cleaned + Country.csv')
